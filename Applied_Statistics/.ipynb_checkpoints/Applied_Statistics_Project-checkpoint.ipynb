# %% [markdown]
# # Statistical Learning Project

# %% [markdown]
# ## Context

# %% [markdown]
# Leveraging customer information is paramount for most businesses. In the case of an insurance company, attributes of customers like the ones mentioned below can be crucial in making business decisions. Hence, knowing to explore
# and generate value out of such data can be an invaluable skill to have.

# %% [markdown]
# ## Objective

# %% [markdown]
# To do statistical analysis and find out insights about the customer information.

# %% [markdown]
# ## Attribute Information

# %% [markdown]
# 1. age: age of primary beneficiary
# 2. sex: insurance contractor gender, female, male
# 3. bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^2) using the ratio of height to weight, ideally 18.5 to 24.9
# 4. children: Number of children covered by health insurance / Number of
# 5. dependents
# 6. smoker: Smoking
# 7. region: the beneficiary's residential area in the US, northeast, southeast,
# 8. southwest, northwest.
# 9. charges: Individual medical costs billed by health insurance.

# %% [markdown]
# ### Question 1: Importing necessary Libraries

# %%
#Importing Libraries
import numpy as np              #Numerical Python Library used for computing multidimensional arrays objects 
import pandas as pd             #Python Data analysis Library. Built on Numpy
import os                       #For using Python utility modules
import matplotlib.pyplot as plt #Plotting lLibrary for Python
import seaborn as sns           #Python Data Vistualization. Built on matplotlib
sns.set(color_codes=True)       #Adds nice background to Graphs
# %matplotlib inline              
                               #Tells Python to display Graph in Jupyter
from scipy.stats import skew 
from scipy import stats

# %% [markdown]
# ### Question 2: Read the data as dataframe

# %%
df= pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Question 3: EDA
# ## 3(a) Shape of the data

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ## 3(b) Datatype of each attribute

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ## 3(c) Checking presence of missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Checking for missing values - Second Way
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Checking for missing values - Third way
df.isna().apply(pd.value_counts)
# Out:
#         age   sex   bmi  children  smoker  region  charges
# False  1338  1338  1338      1338    1338    1338     1338

# %%
#in total
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 3(d) Five point summary of numerical attribute

# %%
#Five point summary includes - Minimun,Lower quartile (Q1 or 25%),Median(Q2 or 50%),Upper quartile (Q3 or 75%) and Maximun
#Using Pandas describe function we can get 5-point summary of numerical attributes very easily 
df.describe().transpose()
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
#  Here, we got min,Q1(25%), Q2(50%), Q3(75%) and max of Numerical attributes - Age, BMI, Children and Charges
#
#  - Data looks legit as all the statistics seem reasonable
#  - Looking at the age column, data looks representative of the true age distribution of the adult population
#  - Very few people have more than 2 children. 75% of the people have 2 or less children
#  - The claimed amount is higly skewed as most people would require basic medi-care and only few suffer from                diseases which cost more to get rid of

# %% [markdown]
# ## 3(e) Distribution of 'bmi', 'age' and 'charges' columns

# %%
Cols = ['bmi', 'charges', 'age']
pos =1
plt.figure(figsize= (20,15))
for i in Cols:
        plt.subplot(3,3,pos)
        sns.distplot(df[i], color='green')
        pos+=1

# %% [markdown]
# - bmi looks quiet normally distributed
#
# - Age seems be be distributed quiet uniformly
#
# - As seen in the previous step, charges are highly skewed

# %% [markdown]
# ## 3(f) Measures of Skewness of 'bmi', 'age' and 'charges' columns

# %%
#Skewness - It is measure of Asymmetry. It helps in checking whether data in observation is concentrated on one side

# Skewness = 0 : Normally distributed.
# Skewness > 0 : More weight in the left tail of the distribution.
# Skewness < 0 : More weight in the right tail of the distribution.


Skewness = pd.DataFrame({'Skewness' : [stats.skew(df.bmi),stats.skew(df.age),stats.skew(df.charges)]},
                        index=['bmi','age','charges'])  # Measure the skeweness of the required columns
Skewness
# Out:
#          Skewness
# bmi      0.283729
# age      0.055610
# charges  1.514180

# %%
df.skew(axis=0,skipna=True)
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %% [markdown]
# - Skew of bmi is very less as seen in the previous step
#
# - age is uniformly distributed and there's hardly any skew
#
# - charges are highly skewed

# %% [markdown]
# ## 3(g) Checking the presence of outliers in 'bmi', 'age' and 'charges' columns

# %%
#Outliers : definition
#Using Boxplot we can findout outliers 
# 1. BMI
df.boxplot(figsize=(10,5), color='red')

# %% [markdown]
# There are outliers in bmi and charges columns

# %% [markdown]
# ## 3(h) Distribution of Categorical columns(include "Children")

# %%
plt.figure(figsize=(20,25))


x = df.smoker.value_counts().index    #Values for x-axis
y = [df['smoker'].value_counts()[i] for i in x]   # Count of each class on y-axis

plt.subplot(4,2,1)
plt.bar(x,y, align='center',color = 'lightblue',edgecolor = 'black',alpha = 0.7)  #plot a bar chart
plt.xlabel('Smoker?')
plt.ylabel('Count ')
plt.title('Smoker distribution')

x1 = df.sex.value_counts().index    #Values for x-axis
y1 = [df['sex'].value_counts()[j] for j in x1]   # Count of each class on y-axis

plt.subplot(4,2,2)
plt.bar(x1,y1, align='center',color = 'lightblue',edgecolor = 'black',alpha = 0.7)  #plot a bar chart
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender distribution')

x2 = df.region.value_counts().index    #Values for x-axis
y2 = [df['region'].value_counts()[k] for k in x2]   # Count of each class on y-axis

plt.subplot(4,2,3)
plt.bar(x2,y2, align='center',color = 'lightblue',edgecolor = 'black',alpha = 0.7)  #plot a bar chart
plt.xlabel('Region')
plt.ylabel('Count ')
plt.title("Regions' distribution")

x3 = df.children.value_counts().index    #Values for x-axis
y3 = [df['children'].value_counts()[l] for l in x3]   # Count of each class on y-axis

plt.subplot(4,2,4)
plt.bar(x3,y3, align='center',color = 'lightblue',edgecolor = 'black',alpha = 0.7)  #plot a bar chart
plt.xlabel('No. of children')
plt.ylabel('Count ')
plt.title("Children distribution")

plt.show()

# %% [markdown]
# - There are a lot more non-smokers than there are smokers in the data
#
# - Instances are distributed evenly accross all regions
#
# - Gender is also distributed evenly
#
# - Most instances have less than 2 children and very few have 4 or 5 children
# Bi-variate distribution of every possible attribute pair

# %% [markdown]
# ## 3(i) Pair plot that includes all the columns of data frame

# %%
#Pairplot plots pairwise relationship in a dataset. It is a simple way to visuslize pairwise relationship between each variable.

sns.pairplot(df[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']]);

# %% [markdown]
# **Here we can see only "NUMERICAL COLUMNS" being plotted. Because pairplot is used to plot "NUMERICAL" columns.
#   In the question , we have to plot ALL columns using pairplot. To achieve this, we have to convert "categorical"
#   column to "numerical" column. We can use "One-Hot Encoding" which uses "Dummy variables" mechanism or we can use Label encoder

# %% [markdown]
# **One-Hot-Encoding is used to create dummry variables to replace the categories in a categorical variable into features of each category and represent it using 1 or 0 based on the presence or absence of the categorical value in the record.**

# %%
#we have following categorical columns - SEX, SMOKER, REGION
#Creating copy of dataset so that original dataset remains same
from sklearn.preprocessing import LabelEncoder
df_new = df.copy(deep=True)
df_new.loc[:,['sex', 'smoker', 'region']] = df_new.loc[:,['sex', 'smoker', 'region']].apply(LabelEncoder().fit_transform) 

sns.pairplot(df_new);

# %% [markdown]
# - The only obvious correlation of 'charges' is with 'smoker'
#
# - Looks like smokers claimed more money than non-smokers
#
# - There's an interesting pattern between 'age' and 'charges. Could be because for the same ailment, older people are charged more than the younger ones

# %% [markdown]
# ### Question 4: Answer the question with Statistical Evidence

# %% [markdown]
# ## 4(a) : Do 'charges' of people who smoke differ significantly from the people who don't?

# %%
#Here, Charges is Numerical(continous) column and Smoke is categorical column.
#When we have one Numerical and one Categorical column with 2 or more categories - Then we go for 1- way ANOVA
#ANOVA uses F-tests to statistically test the equality of means.

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
#Scatter plot to look for visual evidence of dependency between attributes smoker and charges accross different ages
plt.figure(figsize=(8,6))
sns.scatterplot( df.age,df.charges,hue=df.smoker,palette= ['red','green'] ,alpha=0.6)
plt.show()

# %% [markdown]
# **Visually the difference between charges of smokers and charges of non-smokers is apparent**

# %% [markdown]
# Step-1 : State Null Hypothesis and Alternate Hypothesis
#
#            H0 = There is no difference in charges between smokers and non-smokers
#
#            Ha = There is a difference in charges between smokers and non-smokers
#
#   Step-2 : Decide Significance level:
#
#               alpha = 0.05
#
#   Step-3 : Identify the test
#
#              Here we have one numerical and one categorical column so we can go for one-way ANOVA
#
#   Step-4 : Calculate p-value using ANOVA table.

# %%
#Calculating p-value
import statsmodels.api as sm
from statsmodels.formula.api import ols

mod = ols('charges ~ smoker', data = df).fit()
aov_table = sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq            F         PR(>F)
# smoker       1.0  1.215199e+11  1.215199e+11  2177.614868  8.271436e-283
# Residual  1336.0  7.455432e+10  5.580413e+07          NaN            NaN

# %% [markdown]
# **Here p-value is less than significance level. So we reject Null Hypothesis.Hence, there is a difference of charges of between smokers and non-smokers.Smokers seem to claim significantly more money than non-smokers**

# %% [markdown]
# ## 4(b) : Does bmi of males differ significantly from that of females?

# %%
#Here, bmi is Numerical(continous) column and Sex is categorical column - Male/Female
#When we have one Numerical and one Categorical column with 2 or more categories - Then we go for 1- way ANOVA
#ANOVA uses F-tests to statistically test the equality of means.

#First check the how much is ths vaiance between two by visualizing it.
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df.age, df.charges,hue=df.sex,palette= ['blue','yellow'] )
plt.show()

# %% [markdown]
# **Visually, there is no apparent relation between gender and charges**

# %% [markdown]
# Step-1 : State Null Hypothesis and Alternate Hypothesis
#
#            H0 = There is no difference in BMI between male and female
#
#            Ha = There is a difference in BMI between male and female
#
#   Step-2 : Decide Significance level:
#
#               alpha = 0.05
#
#   Step-3 : Identify the test
#
#              Here we have one numerical and one categorical column so we can go for one-way ANOVA
#
#   Step-4 : Calculate p-value using ANOVA table.

# %%
#Calculating p-value
import statsmodels.api as sm
from statsmodels.formula.api import ols

mod = ols('bmi ~ sex', data = df).fit()
aov_table = sm.stats.anova_lm(mod, type =2)
print(aov_table)
# Out:
#               df        sum_sq     mean_sq        F    PR(>F)
# sex          1.0    106.912532  106.912532  2.87897  0.089976
# Residual  1336.0  49613.287854   37.135695      NaN       NaN

# %% [markdown]
# **Here, value of p (0.089976) is greater than significance level (0.05). So we "fail to reject" Null Hypothesis. Hence , there is no difference in BMI of Male and Female. bmi of both the genders are identical**

# %% [markdown]
# ## 4(c) : Is the proportion of smokers significantly different in different genders?

# %% [markdown]
# ### Test of proportions:

# %% [markdown]
# Here , Sex(Male/Female) and smokers(Yes/No) are two different categorical variables.
#
# Step-1 : State Null Hypothesis and Alternate Hypothesis
#
#            H0 = Gender has no effect on smoking habits (There is no relationship between 2 categorical variables).
#
#            Ha = Gender has an effect on smoking habits (There is a relationship between 2 categorical variables).
#
#   Step-2 : Decide Significance level:
#
#               alpha = 0.05
#
#   Step-3 : Identify the test
#
#              Here we have two categorical column from single population so we can go for CHI-Square Test.
#              Chi-Square test determines if there is significant association between two variables.
#
#   Step-4 : Calculate p-value using chi-square:

# %%
# Chi_square test to check if smoking habits are different for different genders
Ho = "Gender has no effect on smoking habits"   # Stating the Null Hypothesis
Ha = "Gender has an effect on smoking habits"   # Stating the Alternate Hypothesis

crosstab = pd.crosstab(df['sex'],df['smoker'])  # Contingency table of sex and smoker attributes

chi, p_value, dof, expected =  stats.chi2_contingency(crosstab)

if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{Ha} as the p_value ({p_value.round(3)}) < 0.05')
else:
    print(f'{Ho} as the p_value ({p_value.round(3)}) > 0.05')
crosstab
# Out:
# Gender has an effect on smoking habits as the p_value (0.007) < 0.05
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %% [markdown]
# **Proportion of smokers in males is significantly different from that of the females**

# %%
# Chi_square test to check if smoking habits are different for people of different regions
Ho = "Region has no effect on smoking habits"   # Stating the Null Hypothesis
Ha = "Region has an effect on smoking habits"   # Stating the Alternate Hypothesis

crosstab = pd.crosstab(df['smoker'], df['region'])  # Contingency table of sex and smoker attributes

chi, p_value, dof, expected =  stats.chi2_contingency(crosstab)

if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{Ha} as the p_value ({p_value.round(3)}) < 0.05')
else:
    print(f'{Ho} as the p_value ({p_value.round(3)}) > 0.05')
crosstab
# Out:
# Region has no effect on smoking habits as the p_value (0.062) > 0.05
# region  northeast  northwest  southeast  southwest
# smoker
# no            257        267        273        267
# yes            67         58         91         58

# %% [markdown]
# **Smoking haboits of people of different regions are similar**

# %% [markdown]
# **Here, p-value is less than alpha, so we can Reject H0.Hence, proportion of smoker does differ based on gender.**

# %% [markdown]
# ## 4(d) : Is the distribution of bmi across women with no children,one children and two children , the same ?

# %% [markdown]
# ***Hypothesis testing ***
#
# ***Ho:*** bmi of women with no child = bmi of women with 1 child = bmi of women with 2 children (Null Hypothesis) \
# ***Ha:*** bmi of women with no child, bmi of women with 1 child, bmi of women with 2 are not equal children(Alertnate Hypothesis)

# %%
# Test to see if the distributions of bmi values for females having different number of children, are significantly different
import copy
Ho = "No. of children has no effect on bmi"   # Stating the Null Hypothesis
Ha = "No. of children has an effect on bmi"   # Stating the Alternate Hypothesis


female_df = copy.deepcopy(df[df['sex'] == 'female'])

zero = female_df[female_df.children == 0]['bmi']
one = female_df[female_df.children == 1]['bmi']
two = female_df[female_df.children == 2]['bmi']


f_stat, p_value = stats.f_oneway(zero,one,two)


if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{Ha} as the p_value ({p_value.round(3)}) < 0.05')
else:
    print(f'{Ho} as the p_value ({p_value.round(3)}) > 0.05')
# Out:
# No. of children has no effect on bmi as the p_value (0.716) > 0.05

# %% [markdown]
# **BMI is not changed by the number of children a women has**
